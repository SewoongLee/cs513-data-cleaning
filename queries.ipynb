# %%
import pandas as pd

# %%
dish_df = pd.read_csv('data/original/Dish.csv')
dish_df
# Out:
#             id                                          name  description  \
# 0            1                    Consomme printaniere royal          NaN
# 1            2                                 Chicken gumbo          NaN
# 2            3                           Tomato aux croutons          NaN
# 3            4                               Onion au gratin          NaN
# 4            5                                   St. Emilion          NaN
# ...        ...                                           ...          ...
# 423392  515673                 Boiled: Corned beef & cabbage          NaN
# 423393  515674               Boiled: Knuckle of Veal & Bacon          NaN
# 423394  515675               Roast: Turkey & Cranberry Sauce          NaN
# 423395  515676  Claret: Chateau Larose, Cruse et Fils Freres          NaN
# 423396  515677  Claret: Chateau Lafite, Cruse et Fils Freres          NaN
#
#         menus_appeared  times_appeared  first_appeared  last_appeared  \
# ...

# %%
menu_page_df = pd.read_csv('data/original/MenuPage.csv')
menu_page_df
# Out:
#           id  menu_id  page_number image_id  full_height  full_width  \
# 0        119    12460          1.0  1603595       7230.0      5428.0
# 1        120    12460          2.0  1603596       5428.0      7230.0
# 2        121    12460          3.0  1603597       7230.0      5428.0
# 3        122    12460          4.0  1603598       7230.0      5428.0
# 4        123    12461          1.0  1603591       7230.0      5428.0
# ...      ...      ...          ...      ...          ...         ...
# 66932  77427    35526          6.0  5194216       2772.0      2341.0
# 66933  77428    35526          7.0  5194217       2772.0      2301.0
# 66934  77429    35526          8.0  5194218       2763.0      2530.0
# 66935  77430    35526          1.0  5194219       5440.0      5237.0
# 66936  77431    35526          2.0  5194220       5466.0      5237.0
#
#                                        uuid
# 0      510d47e4-2955-a3d9-e040-e00a18064a99
# 1      510d47e4-2956-a3d9-e040-e00a18064a99
# ...

# %%
menu_df = pd.read_csv('data/original/Menu.csv')
menu_df
# Out:
#           id                                               name  \
# 0      12463                                                NaN
# 1      12464                                                NaN
# 2      12465                                                NaN
# 3      12466                                                NaN
# 4      12467                                                NaN
# ...      ...                                                ...
# 17540  35515                                      Hotel LaSalle
# 17541  35516                                          Dennett's
# 17542  35517                                      The Cortlandt
# 17543  35518           Hotel Schynige Platte und Hotel Bellevue
# 17544  35526  Christmas Dinner, Troop F 19: Fort Huachuca, A...
#
#                                                  sponsor  \
# 0                                          HOTEL EASTMAN
# 1                                       REPUBLICAN HOUSE
# ...

# %% [markdown]
# ## Time format cleaning

# %% [markdown]
# ### Before

# %%
menu_df.loc[~menu_df['date'].str.match(r'[1-2][0-9][0-9][0-9]-[0-1][0-9]-[0-3][0-9]').astype(bool), 'date']
# Out:
# 525      0190-03-06
# 16917    0001-01-01
# 16918    0001-01-01
# Name: date, dtype: object

# %% [markdown]
# ### After

# %%
menu_df.loc[~menu_df['date'].str.match(r'[1-2][0-9][0-9][0-9]-[0-1][0-9]-[0-3][0-9]').astype(bool), 'date'] = None
menu_df.loc[~menu_df['date'].str.match(r'[1-2][0-9][0-9][0-9]-[0-1][0-9]-[0-3][0-9]').astype(bool), 'date']
# Out:
# 525      None
# 16917    None
# 16918    None
# Name: date, dtype: object

# %% [markdown]
# ## ICV about appeared time

# %% [markdown]
# ### Before

# %%
dish_df[dish_df["first_appeared"] > dish_df["last_appeared"]]
# Out:
#             id                                               name  \
# 131193  164029                                   Clear beef broth
# 163257  204888                          Hot roast beef with gravy
# 197050  250693  SURI LEBERLI - Shredded Calf's Liver Flambe in...
# 197053  250699                          SWISS MINCED VEAL, ROESTI
# 237740  301736                                        Cafe Glacee
# 244534  309629                                      Garlic Butter
#
#         description  menus_appeared  times_appeared  first_appeared  \
# 131193          NaN               0               1            1900
# 163257          NaN               0               1            1900
# 197050          NaN               0               1            1945
# 197053          NaN               0               1            1945
# 237740          NaN               0               2            1940
# 244534          NaN               0               1            1947
#
# ...

# %% [markdown]
# ### After

# %%
# ICV query
dish_df = dish_df.drop(dish_df[dish_df["first_appeared"] > dish_df["last_appeared"]].index)
dish_df
# Out:
#             id                                          name  description  \
# 0            1                    Consomme printaniere royal          NaN
# 1            2                                 Chicken gumbo          NaN
# 2            3                           Tomato aux croutons          NaN
# 3            4                               Onion au gratin          NaN
# 4            5                                   St. Emilion          NaN
# ...        ...                                           ...          ...
# 423392  515673                 Boiled: Corned beef & cabbage          NaN
# 423393  515674               Boiled: Knuckle of Veal & Bacon          NaN
# 423394  515675               Roast: Turkey & Cranberry Sauce          NaN
# 423395  515676  Claret: Chateau Larose, Cruse et Fils Freres          NaN
# 423396  515677  Claret: Chateau Lafite, Cruse et Fils Freres          NaN
#
#         menus_appeared  times_appeared  first_appeared  last_appeared  \
# ...

# %% [markdown]
# ## Write cleaned dataframe to new csv file

# %%
menu_df.to_csv('data/cleaned/Menu-cleaned.csv')
dish_df.to_csv('data/cleaned/Dish-cleaned.csv')

# %% [markdown]
# # SQLite

# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect('data.db')

cur = con.cursor()
cur.execute('''
create table Menu (
id integer primary key,
name text,
sponsor text,
event text,
venue text,
place text,
physical_description text,
occasion text,
notes text,
call_number text,
keywords text,
language text,
date text,
location text,
location_type text,
currency text,
currency_symbol text,
status text,
page_count integer,
dish_count integer
)
''')

cur.execute('''
create table Dish (
id integer primary key, 
name text,
description text,
times_appeared integer,
first_appeared integer,
last_appeared integer,
lowest_price real,
highest_price real
)
''')

cur.execute('''
create table MenuItem (
id integer primary key,
menu_page_id integer,
price integer,
high_price integer,
dish_id integer,
created_at text,
updated_at text,
xpos real,
ypos real
)
''')


cur.execute('''
create table MenuPage (
id integer primary key,
menu_id integer,
page_number integer,
image_id integer,
full_height real,
full_width real,
uuid text
)
''')

# %%
df = pd.read_csv('data/original/Menu.csv')

cur.execute('begin')
try:
    for row in df.to_dict(orient='records'):
        cur.execute('insert into Menu values (:id,:name,:sponsor,:event,:venue,:place,:physical_description,:occasion,:notes,:call_number,:keywords,:language,:date,:location,:location_type,:currency,:currency_symbol,:status,:page_count,:dish_count)', row)
    cur.execute('commit')
except:
    cur.execute('rollback')
    raise

# %%
df = pd.read_csv('data/original/Dish.csv')

cur.execute('begin')
try:
    for row in df.to_dict(orient='records'):
        cur.execute('insert into Dish values (:id,:name,:description,:times_appeared,:first_appeared,:last_appeared,:lowest_price,:highest_price)', row)
    cur.execute('commit')
except:
    cur.execute('rollback')
    raise

# %%
df = pd.read_csv('data/original/MenuItem.csv')

cur.execute('begin')
try:
    for row in df.to_dict(orient='records'):
        cur.execute('insert into MenuItem values (:id,:menu_page_id,:price,:high_price,:dish_id,:created_at,:updated_at,:xpos,:ypos)', row)
    cur.execute('commit')
except:
    cur.execute('rollback')
    raise

# %%
df = pd.read_csv('data/original/MenuPage.csv')

cur.execute('begin')
try:
    for row in df.to_dict(orient='records'):
        cur.execute('insert into MenuPage values (:id,:menu_id,:page_number,:image_id,:full_height,:full_width,:uuid)', row)
    cur.execute('commit')
except:
    cur.execute('rollback')
    raise

# %%
# find MenuPage entries that don't have parent Menu 
df = pd.read_sql_query('''
select count(distinct MenuPage.menu_id)
from MenuPage
''', con)

print(df)
# => 19816

df = pd.read_sql_query('''
select count(distinct MenuPage.menu_id)
from MenuPage
left join Menu
on MenuPage.menu_id = Menu.id
where Menu.id is null
''', con)

print(df)
# => 2271

# %%
# find MenuItem entries that don't have parent MenuPage
df = pd.read_sql_query('''
select count(distinct MenuItem.menu_page_id)
from MenuItem
''', con)

print(df)
# => 19816

df = pd.read_sql_query('''
select count(distinct MenuItem.menu_page_id)
from MenuItem
left join MenuPage
on MenuItem.menu_page_id = MenuPage.id
where MenuPage.id is null
''', con)

print(df)
# => 0 (no need for cleaning)

# %%
# find MenuItem entries that don't have parent Dish 
df = pd.read_sql_query('''
select count(distinct MenuItem.dish_id)
from MenuItem
''', con)

print(df)
# => 19816

df = pd.read_sql_query('''
select count(distinct MenuItem.dish_id)
from MenuItem
left join Dish
on MenuItem.dish_id = Dish.id
where Dish.id is null
''', con)

print(df)
# => 3
